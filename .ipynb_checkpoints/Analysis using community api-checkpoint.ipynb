# %% [markdown]
# # Sentiment Analysis of NYTimes community
# - For this question, I am trying to analyze sentiments of people after the results of Presidential Election were declared on 9th of November, 2016
# - For this analysis I have used community api to get data from 11/10/2016 to 11/30/2016

# %%
#Getting api-key from the environment
import os
nyt_community_key = os.getenv('nyt_community_key')

# %%
#Importing Presidential Election data from the community api 
import requests
from pprint import pprint
import json
import time
for i in range(10, 31):
    j=str(i)
    r = requests.get("http://api.nytimes.com/svc/community/v3/user-content/by-date.json?api-key="+nyt_community_key+"&date=2016-11-"+j)   
    data = r.json()
    time.sleep(5)
    #pprint(data)
    with open("data/dataelection"+j+".json", 'w') as outfile:
        json.dump(data, outfile)

# %%
#Reading 1 file at a time to understand the data
import glob
import json
from pprint import pprint
json_files=glob.glob("data/dataelection27.json")
for file in json_files:
    with open(file) as data_file:
        data = json.load(data_file)
        #pprint(data)
# Out:
# {'copyright': 'Copyright (c) 2017 The New York Times Company.  All Rights '
#               'Reserved.',
#  'debug': {'version': 3.1},
#  'results': {'api_timestamp': '1488812852',
#              'comments': [{'approveDate': '1480222868',
#                            'assetID': 3462338,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/the-pretend-populism-of-donald-trump.html',
#                            'commentBody': "Trump's populism is not dependent "
#                                           'upon economics, economic class, or '
#                                           'policy positions.<br/><br/>This '
#                                           'election demonstrated that the '
#                                           'Republican base is indifferent to '
#                                           'sexual scandals, financial '
#                                           'chicanery, and overt expressions of '
#                                           'racism by their candidates.  Forget '
#                                           'about the shallow pretensions of '
#                                           "the 'Moral Majority' of yesteryear "
#                                           '- Trump has demolished the last '
#                                           'remnants of that facade. '
#                                           '<br/><br/>The Republican base voted '
#                                           'for an Attitude, with little '
#                                           'expectation of any actual results '
#                                           'from their candidate. Rhetoric is '
#                                           'more important than results. That '
#                                           'attitude is a snarling, '
#                                           'free-floating cynicism that borders '
#                                           'on outright nihilism that has '
#                                           'become the core of their identity '
#                                           'as Americans. <br/><br/>The '
#                                           'Confederacy thrives on rejecting '
#                                           "the Union, or the 'establishment' "
#                                           "in today's terminology. The Civil "
#                                           'War continues, and to no good or '
#                                           'meaningful end. ',
#                            'commentID': 20617781,
#                            'commentSequence': 20617781,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480222838',
#                            'editorsSelection': 0,
#                            'lft': 562,
#                            'parentID': None,
#                            'recommendationCount': 108,
#                            'replies': {'comments': [{'approveDate': '1480257625',
#                                                      'commentBody': 'Sound '
#                                                                     'familiar '
#                                                                     '......reconstruction '
#                                                                     '1865.',
#                                                      'commentID': 20618098,
#                                                      'commentSequence': 20618098,
#                                                      'commentTitle': 'n/a',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480227032',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617781,
#                                                      'parentUserDisplayName': 'Jonathan '
#                                                                               'Baker',
#                                                      'recommendations': 1,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480257625',
#                                                      'userDisplayName': 'Angela',
#                                                      'userID': 77954089,
#                                                      'userLocation': 'Brooklyn',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'}]},
#                            'replyCount': 1,
#                            'rgt': 565,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222868',
#                            'userDisplayName': 'Jonathan Baker',
#                            'userID': 59697229,
#                            'userLocation': 'NYC',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480222869',
#                            'assetID': 3462338,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/the-pretend-populism-of-donald-trump.html',
#                            'commentBody': 'We will all become the '
#                                           'social-engineering playthings of a '
#                                           'few plutocrats, just like all these '
#                                           'thousands of poor students in '
#                                           'Detroit, whose lives were destroyed '
#                                           "by Betsy DeVos's disastrous charter "
#                                           'school experimentations.  '
#                                           "<br/><br/>But let's look at the "
#                                           'bright side: it will all make for '
#                                           'darling cocktail chatter, as Betsy '
#                                           'and her ilk gather to think about '
#                                           'how to experiment next with the '
#                                           'little people, reveling in the '
#                                           'vainglorious certainty that obscene '
#                                           'inherited wealth produces valuable '
#                                           'ideas and useful expertise in '
#                                           'addressing complex public policy '
#                                           'issues. ',
#                            'commentID': 20617779,
#                            'commentSequence': 20617779,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480222830',
#                            'editorsSelection': 0,
#                            'lft': 566,
#                            'parentID': None,
#                            'recommendationCount': 96,
#                            'replies': {'comments': [{'approveDate': '1480228685',
#                                                      'commentBody': 'How much '
#                                                                     'damage '
#                                                                     'can one '
#                                                                     'family '
#                                                                     'inflict '
#                                                                     '-- with '
#                                                                     'her '
#                                                                     'brother '
#                                                                     'head of '
#                                                                     'Blackwater!',
#                                                      'commentID': 20618223,
#                                                      'commentSequence': 20618223,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480228678',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617779,
#                                                      'parentUserDisplayName': 'Natalie',
#                                                      'recommendations': 28,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 1,
#                                                      'updateDate': '1480228685',
#                                                      'userDisplayName': 'Ann',
#                                                      'userID': 31713359,
#                                                      'userLocation': 'California',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'}]},
#                            'replyCount': 1,
#                            'rgt': 569,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222869',
#                            'userDisplayName': 'Natalie',
#                            'userID': 16507503,
#                            'userLocation': 'New York',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480222870',
#                            'assetID': 3462338,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/the-pretend-populism-of-donald-trump.html',
#                            'commentBody': '"With Trump the plutocracy has '
#                                           'taken over '
#                                           'Washington"<br/><br/>Hillary was '
#                                           'not plutocracy? What was Trump '
#                                           'running against, Bernie? It was the '
#                                           'plutocratic status quo that has '
#                                           'looted this country for themselves, '
#                                           'and all their wars and twisted '
#                                           'economics.<br/><br/>In most places '
#                                           'across this whole country, enough '
#                                           'people disliked Hillary so much '
#                                           "they'd vote for even Trump just to "
#                                           'reject her.',
#                            'commentID': 20617773,
#                            'commentSequence': 20617773,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480222806',
#                            'editorsSelection': 0,
#                            'lft': 495,
#                            'parentID': 20617307,
#                            'recommendationCount': 12,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 496,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222870',
#                            'userDisplayName': 'Mark Thomason',
#                            'userID': 37674938,
#                            'userLocation': 'Clawson, Mich',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480222926',
#                            'assetID': 3462336,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/election-therapy-from-my-basket-of-deplorables.html',
#                            'commentBody': 'R. Law &amp; gemli:<br/><br/>I may '
#                                           'slip occasionally, but I have begun '
#                                           'to lower-case his name.  To '
#                                           'maintain respect for the office, '
#                                           'come January 20 it will be '
#                                           'President trump.',
#                            'commentID': 20617785,
#                            'commentSequence': 20617785,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480222866',
#                            'editorsSelection': 0,
#                            'lft': 103,
#                            'parentID': 20614366,
#                            'recommendationCount': 26,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 104,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222926',
#                            'userDisplayName': 'mancuroc',
#                            'userID': 12582762,
#                            'userLocation': 'Rochester',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480222987',
#                            'assetID': 3462338,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/the-pretend-populism-of-donald-trump.html',
#                            'commentBody': 'Why is anyone '
#                                           'surprised?<br/><br/>He said he was '
#                                           'gonna hire "experts" - he just '
#                                           'didn\'t say "experts in getting '
#                                           'money."<br/><br/>From the Amway '
#                                           'DeVos clan (MLM scheme) to the '
#                                           'Crisis Consultants (Rudy profiting '
#                                           'off 9/11) to the extractive energy '
#                                           "despoilers...<br/><br/>they've all "
#                                           "gotten rich from other people's "
#                                           "sweat, other people's tears, other "
#                                           "people's land and "
#                                           'water.<br/><br/>Why is anyone '
#                                           'surprised that a huckster prefers '
#                                           'the company of hucksters?',
#                            'commentID': 20617792,
#                            'commentSequence': 20617792,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480222972',
#                            'editorsSelection': 0,
#                            'lft': 570,
#                            'parentID': None,
#                            'recommendationCount': 117,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 571,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222987',
#                            'userDisplayName': 'RoughAcres',
#                            'userID': 21674888,
#                            'userLocation': 'New York',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480222988',
#                            'assetID': 3462337,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/can-senate-democrats-save-the-party.html',
#                            'commentBody': 'What the GOP has learned over the '
#                                           'past decade is that compromise is '
#                                           'not rewarded by voters or the '
#                                           'media. Instead, being a true '
#                                           'opposition party that sets its own '
#                                           'agenda and fights every step of the '
#                                           'way is the path to victory. '
#                                           '<br/><br/>It is time for the '
#                                           'Democrats in the Senate and '
#                                           'elsewhere to learn that lesson and '
#                                           'flip the script on the GOP.  Do not '
#                                           'enable, normalize, or compromise '
#                                           'with the phony populist con man who '
#                                           'lost the popular vote by more than '
#                                           '2 million votes yet will be our '
#                                           'next President, and do not '
#                                           'compromise with or enable the Koch '
#                                           "Brothers' GOP lackeys in the Senate "
#                                           'and House. Instead, Democrats must '
#                                           'set forth their own populist '
#                                           'progressive economic agenda, and '
#                                           'fight the coming Republican efforts '
#                                           'to privatize Medicare and Social '
#                                           'Security, destroy ObamaCare and '
#                                           'public education, and line the '
#                                           'pockets of billionaires. If Trump '
#                                           'or other Republicans want to come '
#                                           'across the aisle and support part '
#                                           "of our agenda, great. But don't "
#                                           'water down our message or normalize '
#                                           'the Republicans by constantly '
#                                           'chasing compromises with the GOP '
#                                           'that always turn out badly for us. '
#                                           '<br/><br/>Infrastructure is a case '
#                                           'in point. Trump\'s "plan" is simply '
#                                           'a corporate tax giveaway to finance '
#                                           'toll roads. Democrats must oppose '
#                                           'that, and offer actual '
#                                           'infrastructure investments instead, '
#                                           "rather than trying to tweak Trump's "
#                                           'plan to make it slightly less bad. '
#                                           'The path to victory is standing up '
#                                           'and fighting, not weak '
#                                           'compromising.<br/><br/><a '
#                                           'href="https://www.facebook.com/WinningProgressive" '
#                                           'title="https://www.facebook.com/WinningProgressive" '
#                                           'target="_blank">https://www.facebook.com/WinningProgressive</a> ',
#                            'commentID': 20617788,
#                            'commentSequence': 20617788,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480222943',
#                            'editorsSelection': 0,
#                            'lft': 330,
#                            'parentID': None,
#                            'recommendationCount': 221,
#                            'replies': {'comments': [{'approveDate': '1480256302',
#                                                      'commentBody': 'You '
#                                                                     'misspelled '
#                                                                     '"President".  '
#                                                                     'From now '
#                                                                     'on, it is '
#                                                                     '"president" '
#                                                                     'trump.  '
#                                                                     '(You can '
#                                                                     'capitalize '
#                                                                     'the "T" '
#                                                                     'in trump '
#                                                                     'if you '
#                                                                     'want.  '
#                                                                     "It's "
#                                                                     'optional.)',
#                                                      'commentID': 20617937,
#                                                      'commentSequence': 20617937,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480224737',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617788,
#                                                      'parentUserDisplayName': 'Winning '
#                                                                               'Progressive',
#                                                      'recommendations': 1,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480256302',
#                                                      'userDisplayName': 'Steve',
#                                                      'userID': 21208144,
#                                                      'userLocation': 'Los '
#                                                                      'Angeles, '
#                                                                      'CA',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'},
#                                                     {'approveDate': '1480260077',
#                                                      'commentBody': 'THe '
#                                                                     'problem '
#                                                                     'is the '
#                                                                     'Dems are '
#                                                                     'always in '
#                                                                     'reactive '
#                                                                     'mode. You '
#                                                                     'say they '
#                                                                     'must come '
#                                                                     'up with '
#                                                                     'economic '
#                                                                     'plans and '
#                                                                     'infrastructure '
#                                                                     'plans. '
#                                                                     'Why '
#                                                                     "didn't "
#                                                                     'they '
#                                                                     'already '
#                                                                     'have '
#                                                                     'them? '
#                                                                     'They just '
#                                                                     'take for '
#                                                                     'granted '
#                                                                     'everyone '
#                                                                     'under 60 '
#                                                                     'and '
#                                                                     'non-white '
#                                                                     'will vote '
#                                                                     'for them '
#                                                                     'so they '
#                                                                     'just '
#                                                                     "don't "
#                                                                     'stand for '
#                                                                     'anything '
#                                                                     'long '
#                                                                     'term.<br/>For '
#                                                                     'the GOP '
#                                                                     'it is '
#                                                                     'pretty '
#                                                                     'simple '
#                                                                     'like it '
#                                                                     'or not. '
#                                                                     'They are '
#                                                                     'for lower '
#                                                                     'taxes, '
#                                                                     'less '
#                                                                     'government '
#                                                                     'regulations, '
#                                                                     'free '
#                                                                     'markets '
#                                                                     'and '
#                                                                     'trickle '
#                                                                     'down '
#                                                                     'econ. '
#                                                                     "Can't say "
#                                                                     'it simply '
#                                                                     'for the '
#                                                                     'Dems. ',
#                                                      'commentID': 20619729,
#                                                      'commentSequence': 20619729,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480253437',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617788,
#                                                      'parentUserDisplayName': 'Winning '
#                                                                               'Progressive',
#                                                      'recommendations': 3,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480260077',
#                                                      'userDisplayName': 'MP',
#                                                      'userID': 117042,
#                                                      'userLocation': 'FL',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'},
#                                                     {'approveDate': '1480265825',
#                                                      'commentBody': '@Winning '
#                                                                     'Progressive<br/>True, '
#                                                                     'but the '
#                                                                     'fundamental '
#                                                                     'problem '
#                                                                     'is that '
#                                                                     'the '
#                                                                     'Democrats '
#                                                                     'do not '
#                                                                     'represent '
#                                                                     'or care '
#                                                                     'about a '
#                                                                     'populist '
#                                                                     'economic '
#                                                                     'agenda. '
#                                                                     'The vast '
#                                                                     'majority '
#                                                                     'are '
#                                                                     'working '
#                                                                     'on behalf '
#                                                                     'of the '
#                                                                     'corporate '
#                                                                     'donors '
#                                                                     'who '
#                                                                     'funded '
#                                                                     'their '
#                                                                     'campaigns, '
#                                                                     'just like '
#                                                                     'their '
#                                                                     'Republican '
#                                                                     'colleagues.',
#                                                      'commentID': 20621465,
#                                                      'commentSequence': 20621465,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480263448',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617788,
#                                                      'parentUserDisplayName': 'Winning '
#                                                                               'Progressive',
#                                                      'recommendations': 1,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480265825',
#                                                      'userDisplayName': 'anne',
#                                                      'userID': 27162868,
#                                                      'userLocation': 'il',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'}]},
#                            'replyCount': 3,
#                            'rgt': 337,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480222988',
#                            'userDisplayName': 'Winning Progressive',
#                            'userID': 61073654,
#                            'userLocation': 'Philadelphia, PA',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480223047',
#                            'assetID': 3462338,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/opinion/sunday/the-pretend-populism-of-donald-trump.html',
#                            'commentBody': 'The most alarming appointment in '
#                                           'this brood of billionaires is Betsy '
#                                           'Devos. She is a politically '
#                                           'partisan Right Wing '
#                                           'Conservative,who wants reduce the '
#                                           'power of teachers and destroy the '
#                                           "political power of teacher's "
#                                           'unions. She has no professional '
#                                           'educational experience or training, '
#                                           'her  attitude toward the LGBT '
#                                           'community can only be described as '
#                                           'homophobic, she never attended '
#                                           'public schools, believes Global '
#                                           'Warming is a hoax, and her primary '
#                                           'activity has been to lobby for '
#                                           'vouchered charter schools, '
#                                           'transferring money from financially '
#                                           'strapped public schools to '
#                                           'religious and private schools. How '
#                                           'can anyone with no professional '
#                                           'resume, who endorses gender bigotry '
#                                           'and anti- science imbecility, be '
#                                           'Secretary of Education in a '
#                                           'culturally pluralistic society like '
#                                           'ours.',
#                            'commentID': 20617794,
#                            'commentSequence': 20617794,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480222986',
#                            'editorsSelection': 0,
#                            'lft': 572,
#                            'parentID': None,
#                            'recommendationCount': 161,
#                            'replies': {'comments': [{'approveDate': '1480253394',
#                                                      'commentBody': '@Montreal '
#                                                                     'Moe, Very '
#                                                                     'Interesting '
#                                                                     'comment '
#                                                                     'Moe I '
#                                                                     'lived in '
#                                                                     'East '
#                                                                     'Grand '
#                                                                     'Rapids as '
#                                                                     'a child '
#                                                                     'and went '
#                                                                     'to '
#                                                                     'Lakeside '
#                                                                     'elementary.I '
#                                                                     'think '
#                                                                     'Betsy may '
#                                                                     'really '
#                                                                     'believe '
#                                                                     'in  the '
#                                                                     'concept '
#                                                                     'of the '
#                                                                     '"elect", '
#                                                                     'which '
#                                                                     'when '
#                                                                     'coupled '
#                                                                     'with the '
#                                                                     'nefarious  '
#                                                                     'idea of '
#                                                                     '"predestination", '
#                                                                     'has a '
#                                                                     'self '
#                                                                     'aggrandizing  '
#                                                                     'effect. '
#                                                                     'Her '
#                                                                     'brother '
#                                                                     'after all '
#                                                                     'founded '
#                                                                     '"Blackwater", '
#                                                                     'now Xe.',
#                                                      'commentID': 20618687,
#                                                      'commentSequence': 20618687,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480237712',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617794,
#                                                      'parentUserDisplayName': 'Don '
#                                                                               'Shipp,',
#                                                      'recommendations': 3,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480253394',
#                                                      'userDisplayName': 'Don '
#                                                                         'Shipp,',
#                                                      'userID': 18855202,
#                                                      'userLocation': 'Homestead '
#                                                                      'Florida',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'},
#                                                     {'approveDate': '1480259050',
#                                                      'commentBody': 'Perhaps '
#                                                                     'we were '
#                                                                     'lucky, '
#                                                                     'had '
#                                                                     'Liberty '
#                                                                     'University '
#                                                                     'President '
#                                                                     'Jerry '
#                                                                     'Falwell '
#                                                                     'Jr. '
#                                                                     'accepted '
#                                                                     'the job '
#                                                                     'as he '
#                                                                     'says '
#                                                                     'President '
#                                                                     'elect-Donald '
#                                                                     'Trump '
#                                                                     'offered, '
#                                                                     'we might '
#                                                                     'well have '
#                                                                     'been on '
#                                                                     'our way '
#                                                                     'to laying '
#                                                                     'the '
#                                                                     'foundations '
#                                                                     'of a '
#                                                                     'theocracy.<br/>Just '
#                                                                     'think how '
#                                                                     'difficult '
#                                                                     'it is to '
#                                                                     'uproot '
#                                                                     'the '
#                                                                     'Taliban... '
#                                                                     'and when '
#                                                                     'the '
#                                                                     'better '
#                                                                     'half of '
#                                                                     'us  are '
#                                                                     'relegated '
#                                                                     'back to '
#                                                                     'the '
#                                                                     'kitchen...',
#                                                      'commentID': 20618729,
#                                                      'commentSequence': 20618729,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480238736',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617794,
#                                                      'parentUserDisplayName': 'Don '
#                                                                               'Shipp,',
#                                                      'recommendations': 1,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480259050',
#                                                      'userDisplayName': 'seanseamour',
#                                                      'userID': 60072525,
#                                                      'userLocation': 'Mediterranean '
# ...
#                           {'approveDate': '1480225653',
#                            'assetID': 3462334,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/us/politics/donald-trump-international-business.html',
#                            'commentBody': 'This article is not about '
#                                           "HRC.<br/>It's about Trump.<br/>Even "
#                                           'if everything you wrote about her '
#                                           'is correct how is it '
#                                           'relevant<br/>Do not think making '
#                                           'her look bad makes Trump look '
#                                           'good.<br/>Trump is a joke.<br/>He '
#                                           'has no right to be President if he '
#                                           'thinks he can be one and still be '
#                                           'the head of a international '
#                                           'business empire.<br/>He can be one '
#                                           'of either but not both..',
#                            'commentID': 20617227,
#                            'commentSequence': 20617227,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480218268',
#                            'editorsSelection': 0,
#                            'lft': 947,
#                            'parentID': 20615420,
#                            'recommendationCount': 7,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 948,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480225653',
#                            'userDisplayName': 'John',
#                            'userID': 65350196,
#                            'userLocation': 'Canada',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480225653',
#                            'assetID': 3462334,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/us/politics/donald-trump-international-business.html',
#                            'commentBody': 'This extensive account makes plain '
#                                           'what many already know: fascism has '
#                                           'come to the United States. There '
#                                           'will be little accountability if we '
#                                           'allow this super-rich autocrat and '
#                                           'his billionaire henchmen to plunder '
#                                           'the Treasury, privatizing '
#                                           'everything, putting public funds at '
#                                           'risks for private profit. Not to '
#                                           'mention the other issues of having '
#                                           'an authoritarian in power. '
#                                           '<br/><br/> We do not have to allow '
#                                           'it. See you in DC on January 20. ',
#                            'commentID': 20617254,
#                            'commentSequence': 20617254,
#                            'commentTitle': '<br/>',
#                            'commentType': 'comment',
#                            'createDate': '1480218447',
#                            'editorsSelection': 0,
#                            'lft': 1384,
#                            'parentID': None,
#                            'recommendationCount': 43,
#                            'replies': {'comments': [{'approveDate': '1480255264',
#                                                      'commentBody': 'Excuse '
#                                                                     'me, but '
#                                                                     'can you '
#                                                                     'spell '
#                                                                     'Solyndra?  '
#                                                                     'How much '
#                                                                     'public '
#                                                                     'funding '
#                                                                     'was lost '
#                                                                     'in that '
#                                                                     'and other '
#                                                                     'solar '
#                                                                     'adventures?<br/>How '
#                                                                     'much '
#                                                                     'private '
#                                                                     'funding '
#                                                                     'will be '
#                                                                     'lost if '
#                                                                     'the '
#                                                                     'Dakota '
#                                                                     'access '
#                                                                     'pipeline, '
#                                                                     'already '
#                                                                     'extensively '
#                                                                     'vetted '
#                                                                     'and '
#                                                                     'licensed, '
#                                                                     'is not '
#                                                                     'allowed '
#                                                                     'to be '
#                                                                     "completed?<br/>I'm "
#                                                                     'sorry, '
#                                                                     'but you '
#                                                                     'have it '
#                                                                     'backwards.',
#                                                      'commentID': 20619188,
#                                                      'commentSequence': 20619188,
#                                                      'commentTitle': '<br/>',
#                                                      'commentType': 'userReply',
#                                                      'createDate': '1480247921',
#                                                      'depth': 1,
#                                                      'editorsSelection': False,
#                                                      'parentID': 20617254,
#                                                      'parentUserDisplayName': 'Henry '
#                                                                               'Hughes',
#                                                      'recommendations': 0,
#                                                      'recommendedFlag': 0,
#                                                      'replies': [],
#                                                      'replyCount': 0,
#                                                      'status': 'approved',
#                                                      'trusted': 0,
#                                                      'updateDate': '1480255264',
#                                                      'userDisplayName': 'Lcnyc',
#                                                      'userID': 58281441,
#                                                      'userLocation': 'New '
#                                                                      'York, '
#                                                                      'New York',
#                                                      'userTitle': 'NULL',
#                                                      'userURL': 'NULL'}]},
#                            'replyCount': 1,
#                            'rgt': 1387,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480225653',
#                            'userDisplayName': 'Henry Hughes',
#                            'userID': 66934692,
#                            'userLocation': 'Marblemount, Washington',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480225653',
#                            'assetID': 3462334,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/us/politics/donald-trump-international-business.html',
#                            'commentBody': "I doubt Trump's supporters read the "
#                                           'NYT, but, I agree, if this were '
#                                           'broadcast six months ago, maybe the '
#                                           'outcome would have been different.  '
#                                           "Yet, we had Trump's verbal account "
#                                           'of sexual harassment, his racists '
#                                           'statement and bold faced lies and, '
#                                           'all of that, as shocking as it was, '
#                                           'had little influence on his '
#                                           'supporters.  ',
#                            'commentID': 20617296,
#                            'commentSequence': 20617296,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480218729',
#                            'editorsSelection': 0,
#                            'lft': 297,
#                            'parentID': 20614506,
#                            'recommendationCount': 4,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 298,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480225653',
#                            'userDisplayName': 'RC',
#                            'userID': 65132443,
#                            'userLocation': 'Midland, MI',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480225653',
#                            'assetID': 3462334,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/us/politics/donald-trump-international-business.html',
#                            'commentBody': 'Professor Lawrence Lessig, himself '
#                                           'a presidential candidate briefly, '
#                                           'wrote in the Wash Post that the '
#                                           'Electoral College could save the '
#                                           'nation by exercising the powers '
#                                           'intended for it by the framers of '
#                                           'the Constitution, the ability to '
#                                           'override the verdict of the states '
#                                           'and, in this case, declare the '
#                                           'person who got the most votes as '
#                                           'president.<br/><br/>Here is a link '
#                                           'to that article: <a '
#                                           'href="http://tinyurl.com/zeljjvd" '
#                                           'title="http://tinyurl.com/zeljjvd" '
#                                           'target="_blank">http://tinyurl.com/zeljjvd</a><br/><br/>There '
#                                           'was a time when public pressure and '
#                                           'media coverage might change the '
#                                           'course of history, but we have '
#                                           'become so bitterly divided along '
#                                           'partisan lines that most of those '
#                                           'who supported Trump would '
#                                           'automatically reject the facts '
#                                           'about his conflicts. There is no '
#                                           'mechanism, no safety check, other '
#                                           'than the EC and, after that, '
#                                           'impeachment proceedings.',
#                            'commentID': 20617331,
#                            'commentSequence': 20617331,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480218958',
#                            'editorsSelection': 0,
#                            'lft': 1001,
#                            'parentID': 20615815,
#                            'recommendationCount': 6,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 1002,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480225653',
#                            'userDisplayName': 'DOUG Terry',
#                            'userID': 65455323,
#                            'userLocation': 'Beyond the Beltway state of mind',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'},
#                           {'approveDate': '1480225653',
#                            'assetID': 3462334,
#                            'assetURL': 'http://www.nytimes.com/2016/11/26/us/politics/donald-trump-international-business.html',
#                            'commentBody': 'Well, guess what, if Trump is '
#                                           'inaugurated, your life as an '
#                                           'American citizen is over.  Leave '
#                                           "him be?  You haven't been reading "
#                                           'the news lately.  ',
#                            'commentID': 20617345,
#                            'commentSequence': 20617345,
#                            'commentTitle': '<br/>',
#                            'commentType': 'userReply',
#                            'createDate': '1480219074',
#                            'editorsSelection': 0,
#                            'lft': 1183,
#                            'parentID': 20616589,
#                            'recommendationCount': 28,
#                            'replies': [],
#                            'replyCount': 0,
#                            'rgt': 1184,
#                            'status': 'approved',
#                            'statusID': 2,
#                            'updateDate': '1480225653',
#                            'userDisplayName': 'RC',
#                            'userID': 65132443,
#                            'userLocation': 'Midland, MI',
#                            'userTitle': 'NULL',
#                            'userURL': 'NULL'}],
#              'totalCommentsFound': 7692,
#              'totalCommentsReturned': 25},
#  'status': 'OK'}

# %%
#Analysis 1: Lets do sentimental analysis on the comments of users regarding the Presidential Election

# %%
#Reading Election data
import glob
import json
files = []
json_files = glob.glob('data/dataelection*.json')

# %%
#Extracting only comments out of total comments regarding Presidential Election
trump = ["glass-ceiling","election","democrats","republicans","trump","donald","presidency","sorrow","happy","liberalism","voters","politics"]
list_of_comments=[]
for file in json_files:
    with open(file) as data_file:
        data = json.load(data_file)
        x = len(data['results']['comments'])
        #print(x)
        try:
            for i in range (0,x):
                comment=data['results']['comments'][i]['commentBody']
                url=data['results']['comments'][i]['assetURL']
                for word in trump:
                    if word in url:
                        list_of_comments.append(comment)
                        #print(url)
                        #print(comment)
                        #print("------------------------------------------------------------------")
                        if 'replies' in data['results']['comments'][i]:
                            y = len(data['results']['comments'][i]['replies']['comments'])
                            #print("Num of replies is:")
                            #print(y)
                            for j in range(0,y):
                                comment1=data['results']['comments'][i]['replies']['comments'][j]['commentBody']
                                list_of_comments.append(comment1)
                                #print(comment1)
                                #print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                        
                
        except:
            pass
print(len(list_of_comments))
# Out:
# 49

# %%
#Getting list of positive and negative words from csv for analysis
positive_list = []
negative_list = []
import csv

        
with open('que[2]/ana_[2]/positive.csv','r') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        positive_list.append(row[0])

with open('que[2]/ana_[2]/negative.csv','r') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        negative_list.append(row[0])  

#print(negative_list)

# %%
#Analyzing if comments are positive or negative
o_main_pos = 0
o_main_neg = 0
o_main_neu = 0
posi_com = []
nega_com = []
neu_com = []
for comment in list_of_comments:
    count_pos = 0
    count_neg = 0
    for word in comment.split():
        if word in  positive_list:
            count_pos = count_pos + 1
        if word in negative_list:
            count_neg = count_neg + 1   
    if count_pos > count_neg:
        #print("Positive")
        posi_com.append(comment)
        o_main_pos = o_main_pos+1
    elif count_pos < count_neg:
        #print("Negative")
        nega_com.append(comment)
        o_main_neg = o_main_neg+1
    else:
        #print("Neutral")
        neu_com.append(comment)
        o_main_neu = o_main_neu+1
    #print(count_pos)
    #print(count_neg)
print("Number of positive comments about Presidential Election:")
print(o_main_pos)
print("Number of negative comments about Presidential Election:")
print(o_main_neg)
print("NUmber of neutral comments about Presidential Election:")
print(o_main_neu)
# Out:
# Number of positive comments about Presidential Election:
# 15
# Number of negative comments about Presidential Election:
# 18
# NUmber of neutral comments about Presidential Election:
# 16

# %%
#Writing output to a csv file
with open("que[2]/ana_[2]/Trump_Comment_Analysis.csv","w",encoding='utf-8') as myfile1:
    writer = csv.writer(myfile1, delimiter=",", quotechar="|", quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(["Number of Positive Comments","Number of Negative Comments","Number of Neutral Comments"])
    writer.writerow([o_main_pos,o_main_neg,o_main_neu])

# %%
#Thus we can conclude that users choose to stay neutral on this topic.
#Though number of negative comments on this topic is slightly more than positive comments but still we can't infer much
#considering the small amount of data.
#We might come to a better conclusion if there is no data constraints

# %%
#Analysis 2: Lets try to analyze the positive comments on Presidential Elections

# %%
posi_com
# Out:
# ["Participation In a democracy does not have any knowledge/education requirement, and certainly once elected, you are equal among all other elected representatives, So, you don't need to satisfy any of the other lawmakers minimum standards, or expectations.<br/><br/>Democracy is the people electing one among them. That was the idea at least. What we have is a whole different can of worms.",
#  "Participation In a democracy does not have any knowledge/education requirement, and certainly once elected, you are equal among all other elected representatives, So, you don't need to satisfy any of the other lawmakers minimum standards, or expectations.<br/><br/>Democracy is the people electing one among them. That was the idea at least. What we have is a whole different can of worms.",
#  "Participation In a democracy does not have any knowledge/education requirement, and certainly once elected, you are equal among all other elected representatives, So, you don't need to satisfy any of the other lawmakers minimum standards, or expectations.<br/><br/>Democracy is the people electing one among them. That was the idea at least. What we have is a whole different can of worms.",
#  'The views you attribute to Bernie are pure fiction.  His vision of capitalism is mainstream in many of the advanced nations and was the norm here before Saint Ronald came along and began tampering with the social contract. ',
#  'I am encouraging the US to build better rail service and upgrade existing lines. High speed rail would also be nice. I would like to see something like the French TGV I the US. ',
#  '"hold him accountable for adhering to the best of what America is"<br/><br/>How can Trump - or anyone else, for that matter - be held "accountable for adhering to the best of what America is" is something that he\'s _not_ doing ',
#  "Thomas Zaslavsky, 16 Nov post<br/><br/>Dear Mr. Zaslavsky, <br/><br/>Time is what we need, to develop and deploy new technologies for energy production and to better assess the impacts of the changes we are experiencing now. <br/><br/>If CO2 indeed controls the climate, then the news that the acceleration of its growth rate in the atmosphere has stopped, and plateaued at the relatively modest rate of 2 ppm/year, should be greated with joy for all who cherish Earth as humanity's cradle. <br/><br/>This slowing of the acceleration to a relatively low linear rate means that the worst case scenarios projected for global warming will be avoided in the policy-relevant future. <br/><br/>I think that's good news.<br/><br/>What do you think? ",
#  "If DT picks Romney or indeed any other rational 'never Trump' Repub, for a spot in the administration, and they accept, they're exhibiting a great degree of self-sacrifice, in order to try to keep the ship of state on an even keel. We need all sane hands on deck. ",
#  'Perhaps Romney would accept the appointment for the good of our country, hoping he can inject a modicum of intelligent sanity into the administration?',
#  "If DT picks Romney or indeed any other rational 'never Trump' Repub, for a spot in the administration, and they accept, they're exhibiting a great degree of self-sacrifice, in order to try to keep the ship of state on an even keel. We need all sane hands on deck. ",
#  'Perhaps Romney would accept the appointment for the good of our country, hoping he can inject a modicum of intelligent sanity into the administration?',
#  'It\'s a bit more like the crude oil train that stopped for the night above Lac-Mégantic, Québec.  The brakes didn\'t quite work and the train began to move very slowly, then a bit faster.  It eventually rolled, pretty fast, into town, setting it on fire.  Climate change hasn\'t "already" happened.  We\'re merely at the start of a long, nasty runaway situation.  The more carbon dioxide and other greenhouse gases we add to the atmosphere, the longer and faster change will continue.  ',
#  'At first I thought this writer was going to deliver a back handed compliment to Romney and a sarcastic denunciation of Giuliani. Little did I know they were actually serious. According to this writer, Romney is to be disqualified simply because of his pre-election disapproval, "laced with venom" of Mr. Trump. By this measure there are approximately three people who could be in the general cabinet pool and none of them are Rodolfo Giuliani. One advantage of Romney is that he is a proven negotiator. He is essentially a self made man through his wheeler-dealer days at Bain. No such negotiating experience for Rodolfo. His style has always been the "my way or the highway" approach. Romney\' skills might best be used in reforming so called Obamacare. If they are really to do the honest thing, they\'ll say they\'ve done a root and branch overhaul when in reality they simply change the name to Romney-Care. Rodolfo would best if he were put in charge of developing a national policy on the mentally ill who roam our streets. His first hand knowledge of this problem. Anywhere but State would be an improvement. Imagine his first speech to the UN if it resembled his RNC Convention speech at all. He could handle planning the first Putin love fest but not much more.',
#  "We will all become the social-engineering playthings of a few plutocrats, just like all these thousands of poor students in Detroit, whose lives were destroyed by Betsy DeVos's disastrous charter school experimentations.  <br/><br/>But let's look at the bright side: it will all make for darling cocktail chatter, as Betsy and her ilk gather to think about how to experiment next with the little people, reveling in the vainglorious certainty that obscene inherited wealth produces valuable ideas and useful expertise in addressing complex public policy issues. ",
#  "We will all become the social-engineering playthings of a few plutocrats, just like all these thousands of poor students in Detroit, whose lives were destroyed by Betsy DeVos's disastrous charter school experimentations.  <br/><br/>But let's look at the bright side: it will all make for darling cocktail chatter, as Betsy and her ilk gather to think about how to experiment next with the little people, reveling in the vainglorious certainty that obscene inherited wealth produces valuable ideas and useful expertise in addressing complex public policy issues. "]

# %%
#Generating a csv to store these positive comments
with open("que[2]/ana_[2]/Trump_Positive_Comments.csv","w",encoding='utf-8') as myfile1:
    writer_p = csv.writer(myfile1,lineterminator='\n')
    writer_p.writerow(["Positive Comments"])
    for i in range(0,len(posi_com)):
        writer_p.writerow([posi_com[i]])

# %%
#Analysis 3: Lets try to analyze the negative comments on Presidential Elections

# %%
nega_com
# Out:
# ["No one appears to be immune from the problem but those with graduate degrees in the sciences seem to be less affected than others. A four year college degree doesn’t seem to provide that much 'immunization' as engineers are often the 'creation scientists', and some other degrees don’t appear to provide the ability to readily discern fact from fiction.  <br/><br/>Don't forget that about a quarter of Democrat believe in creationism, as do about a quarter of people with college degrees. Democrats are much more likely to want to shut down nuclear power in site of the fact that it has actually saved millions of lives due to less coal being burned. Democrats have pushed for assault weapon bans in spite of the fact that it would have an unmeasurable impact on the national homicide rate, and worse yet while ignoring the primary contributors to firearm homicides in the country.  When values and beliefs are embraced one is at risk as they tend to change slowly, if at all. ",
#  'The common denominator among Trump\'s appointments and inner circle is the sycophantic badge of honor they all hold for following him to the depths of human decency for the sake of enhancing their own careers. Brushing aside his ignorant proclamations, misogynistic outbursts and racist rants. And now, Mitt Romney who warned in March that to chose Trump for President "the prospects for a safe and prosperous future are greatly diminished", comes in search of an appointment. Is there no level they will not stoop to?<br/>What an unseemly spectacle!',
#  'At least Romney is a grownup, though.  At least there will be one flawed but not horribly awful person in their midst.',
#  'The common denominator among Trump\'s appointments and inner circle is the sycophantic badge of honor they all hold for following him to the depths of human decency for the sake of enhancing their own careers. Brushing aside his ignorant proclamations, misogynistic outbursts and racist rants. And now, Mitt Romney who warned in March that to chose Trump for President "the prospects for a safe and prosperous future are greatly diminished", comes in search of an appointment. Is there no level they will not stoop to?<br/>What an unseemly spectacle!',
#  'At least Romney is a grownup, though.  At least there will be one flawed but not horribly awful person in their midst.',
#  "This is absurd. Is the NYT setting its readers up for a shift towards pleasing Trump and his administration? The NYT did not even vet Trump. It ignored the corruption of his foundation and stayed away from reporting in earnest his tangled business dealings and numerous lawsuits that pose more of an ethical threat than the Clinton Foundation ever could have. But only now is Donald being vetted somewhat but after the fact. We heard more about emails than anything else. And that did as much to suppress Clinton's vote as did Comey and the Russians.  I hear a lot of Trump voters who claim that America has become too soft, too much PC and that they are sick of hearing about safe spaces. So why then are they complaining the loudest when Trump Is bashed and criticized? Not all Trump voters are racist BUT all Trump voters knew that he is. So please, NYT, spare me your coddling of the Trump voter. That's not your job.",
#  "Trump's populism is not dependent upon economics, economic class, or policy positions.<br/><br/>This election demonstrated that the Republican base is indifferent to sexual scandals, financial chicanery, and overt expressions of racism by their candidates.  Forget about the shallow pretensions of the 'Moral Majority' of yesteryear - Trump has demolished the last remnants of that facade. <br/><br/>The Republican base voted for an Attitude, with little expectation of any actual results from their candidate. Rhetoric is more important than results. That attitude is a snarling, free-floating cynicism that borders on outright nihilism that has become the core of their identity as Americans. <br/><br/>The Confederacy thrives on rejecting the Union, or the 'establishment' in today's terminology. The Civil War continues, and to no good or meaningful end. ",
#  "Trump's populism is not dependent upon economics, economic class, or policy positions.<br/><br/>This election demonstrated that the Republican base is indifferent to sexual scandals, financial chicanery, and overt expressions of racism by their candidates.  Forget about the shallow pretensions of the 'Moral Majority' of yesteryear - Trump has demolished the last remnants of that facade. <br/><br/>The Republican base voted for an Attitude, with little expectation of any actual results from their candidate. Rhetoric is more important than results. That attitude is a snarling, free-floating cynicism that borders on outright nihilism that has become the core of their identity as Americans. <br/><br/>The Confederacy thrives on rejecting the Union, or the 'establishment' in today's terminology. The Civil War continues, and to no good or meaningful end. ",
#  'How much damage can one family inflict -- with her brother head of Blackwater!',
#  'How much damage can one family inflict -- with her brother head of Blackwater!',
#  '"With Trump the plutocracy has taken over Washington"<br/><br/>Hillary was not plutocracy? What was Trump running against, Bernie? It was the plutocratic status quo that has looted this country for themselves, and all their wars and twisted economics.<br/><br/>In most places across this whole country, enough people disliked Hillary so much they\'d vote for even Trump just to reject her.',
#  'Disbelieving and still suffering from PTSD-type symptoms hearing Trump had become the "president-elect". Then I started to do some research and discovered that 29 million Americans vote on antiquated and insecure voting machines. Two nationally-renown and credible computer experts write:  “We know that the national results could be tipped by manipulating the vote count in a relatively small number of jurisdictions — a few dozen spread across a few key states. We know that the vast majority of local elections officials have limited resources to detect or defend against cyber attacks. And while pre-election polls have large uncertainties, they were consistently off. And various aspects of the preliminary results, such as a high rate of undervotes for president, have aroused suspicion. Source: “Still Time for an Election Audit” – 11/18/2016 – USA Today, by Professors Ron Rivest &amp; Philip Stark',
#  "I believe it is missing the point to suggest that Trump's problem is vanity and ego.<br/>I believe something much more sinister is at play inside of his problematic personality. What that sinister aspect consists of remains to be uncovered. ",
#  'Tim,<br/><br/>You said, " ... Don will have to go into rooms now always face first ..."<br/><br/>And that will cause even more problems because he will have to pause to make a choice of WHICH ONE  to enter with!',
#  '"And to lose to a \'woman\', it\'s unthinkable in his universe."<br/><br/>Especially since his only idea of a winning woman is a not-yet-dressed Miss Universe.',
#  "I believe it is missing the point to suggest that Trump's problem is vanity and ego.<br/>I believe something much more sinister is at play inside of his problematic personality. What that sinister aspect consists of remains to be uncovered. ",
#  'Tim,<br/><br/>You said, " ... Don will have to go into rooms now always face first ..."<br/><br/>And that will cause even more problems because he will have to pause to make a choice of WHICH ONE  to enter with!',
#  '"And to lose to a \'woman\', it\'s unthinkable in his universe."<br/><br/>Especially since his only idea of a winning woman is a not-yet-dressed Miss Universe.']

# %%
#Generating a csv to store these negative comments
with open("que[2]/ana_[2]/Trump_Negative_Comments.csv","w",encoding='utf-8') as myfile2:
    writer_n = csv.writer(myfile2,lineterminator='\n')
    writer_n.writerow(["Negative Comments"])
    for i in range(0,len(nega_com)):
        writer_n.writerow([nega_com[i]])

# %%
#Analysis 4: Lets try to analyze the neutral comments on Presidential Elections

# %%
neu_com
# Out:
# ['no confirmation needed cabinet members are appointed .',
#  'I said it before and I\'ll say it again, we need standards for people who wish to participate in Congress and effect laws that not only impact human beings and life in general in this country as well as globally, but impact them for generations to come.<br/>Just as law makers wouldn\'t tolerate colleagues who aren\'t toilet trained or are unable to find their home state on a map, they also should not tolerate those who apparently couldn\'t manage to pass basic high school math and science. Unfortunately, such seems to be the case for a majority of the Republican law makers.<br/>Interestingly, this willful ignorance puts them at odds with their conservative constituents. According to a poll conducted by ClearPath, conservatives DO favor taking measures against global warming. Take a look at the site below where you will find the link to a PDF with very precise questions on how Republican voters feel about global warming and what to do about it. The answers are astonishing.<br/><a href="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" title="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" target="_blank">http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-r...</a>',
#  'I said it before and I\'ll say it again, we need standards for people who wish to participate in Congress and effect laws that not only impact human beings and life in general in this country as well as globally, but impact them for generations to come.<br/>Just as law makers wouldn\'t tolerate colleagues who aren\'t toilet trained or are unable to find their home state on a map, they also should not tolerate those who apparently couldn\'t manage to pass basic high school math and science. Unfortunately, such seems to be the case for a majority of the Republican law makers.<br/>Interestingly, this willful ignorance puts them at odds with their conservative constituents. According to a poll conducted by ClearPath, conservatives DO favor taking measures against global warming. Take a look at the site below where you will find the link to a PDF with very precise questions on how Republican voters feel about global warming and what to do about it. The answers are astonishing.<br/><a href="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" title="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" target="_blank">http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-r...</a>',
#  'I said it before and I\'ll say it again, we need standards for people who wish to participate in Congress and effect laws that not only impact human beings and life in general in this country as well as globally, but impact them for generations to come.<br/>Just as law makers wouldn\'t tolerate colleagues who aren\'t toilet trained or are unable to find their home state on a map, they also should not tolerate those who apparently couldn\'t manage to pass basic high school math and science. Unfortunately, such seems to be the case for a majority of the Republican law makers.<br/>Interestingly, this willful ignorance puts them at odds with their conservative constituents. According to a poll conducted by ClearPath, conservatives DO favor taking measures against global warming. Take a look at the site below where you will find the link to a PDF with very precise questions on how Republican voters feel about global warming and what to do about it. The answers are astonishing.<br/><a href="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" title="http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-republican-support-for-clean-energy-policies-300150875.html" target="_blank">http://www.prnewswire.com/news-releases/new-national-poll-shows-strong-r...</a>',
#  'Sayeeshwar.......climate change is already happening.  And if you don\'t believe climatologists, maybe you should know it is already a given to horticulturists, foresters, botanists, zoologists, geologists, oceanographers, biologists, etc......who factor it into research on planetary life.  They aren\'t all political about it, and they don\'t all depend on government funding.  Climate change is just the scientifically accepted model.  Really, the only "skeptics" left are industrialists, politicians and their followers, and you don\'t think they have more of an agenda?',
#  "You won't get to McCain without saying he has let down his father,",
#  "Been to Russia twice, Urko.<br/><br/>It's one of the best propaganda-based, manipulative dictatorships on the planet with rigged elections as the soup du jour.<br/><br/>Comey rigged the election very nicely for the tyrannical American right-wing.<br/><br/>Putin must be very proud.",
#  "No.  The probably thought they won, and, come to think about it, so do I.  In fact, didn't Trump say that he never settles?  Oh yeah, he never lies, either.",
#  '"Trump Reassures the Media (For Now)"<br/><br/>The media may be reassured.  I\'m not.  Not even "for now".',
#  'Already donated. Hope they are going to bring in cybersecurity experts to look at the Diebold voting machines to see if they were hacked.',
#  'Sound familiar ......reconstruction 1865.',
#  'Sound familiar ......reconstruction 1865.',
#  "Trump enjoys adulation and attention far more than he cares about the truth.   In his too vivid imagination, it's impossible, literally impossible that he lost the popular vote to Hillary Clinton.   And to lose to a 'woman', it's unthinkable in his universe.<br/><br/>Meanwhile his minions spin tall tales, like Bill O' Reilly tonight issuing the proclamation that it could have happened just this way, that Bill's research team - one of the finest! - went to California and found out just how easy it is easy for 'illegals' to become registered and to vote.   It was easy to imagine Bill with his imaginary Ben Franklin glasses, peering deeply into the faces of his television audience.   The lie must be kept alive!<br/><br/>Meanwhile on planet earth, our president elect has been unremittingly the butt of more jokes than likely any president elect in American history, not only here but around the world.   <br/><br/>We await a deluge of Pinocchio cartoons, interposed with The Donald's face.   With his massively inflated egoistic head, now barely able to pass through normal doorways, Don will have to go into rooms now always face first, as his nose will preclude him from entering any other way.",
#  "Trump enjoys adulation and attention far more than he cares about the truth.   In his too vivid imagination, it's impossible, literally impossible that he lost the popular vote to Hillary Clinton.   And to lose to a 'woman', it's unthinkable in his universe.<br/><br/>Meanwhile his minions spin tall tales, like Bill O' Reilly tonight issuing the proclamation that it could have happened just this way, that Bill's research team - one of the finest! - went to California and found out just how easy it is easy for 'illegals' to become registered and to vote.   It was easy to imagine Bill with his imaginary Ben Franklin glasses, peering deeply into the faces of his television audience.   The lie must be kept alive!<br/><br/>Meanwhile on planet earth, our president elect has been unremittingly the butt of more jokes than likely any president elect in American history, not only here but around the world.   <br/><br/>We await a deluge of Pinocchio cartoons, interposed with The Donald's face.   With his massively inflated egoistic head, now barely able to pass through normal doorways, Don will have to go into rooms now always face first, as his nose will preclude him from entering any other way.",
#  'Correction: "Sago" mine disaster. ',
#  'That made me laugh. Thank you!']

# %%
#Generating a csv to store these neutral comments
with open("que[2]/ana_[2]/Trump_Neutral_Comments.csv","w",encoding='utf-8') as myfile3:
    writer_ne = csv.writer(myfile3,lineterminator='\n')
    writer_ne.writerow(["Neutral Comments"])
    for i in range(0,len(neu_com)):
        writer_ne.writerow([neu_com[i]])

# %%
#Analysis 5: Lets try to find the locations of users of NYTimes.com

# %%
#Reading Election data
import glob
import json
places = []
json_files = glob.glob('data/dataelection*.json')

for file in json_files:
    with open(file) as data_file:
        data = json.load(data_file)
        x = len(data['results']['comments'])
        try:
            for i in range (0,x):
                place=data['results']['comments'][i]['userLocation']
                places.append(place)
        except:
            pass

print(set(places))
# Out:
# {'Falls church, Va', 'Santa Barbara, ca', 'Maine', 'Tucson', 'Manhattanville', 'Reno, NV', 'Vermont', 'Paris, France', 'boston', 'Canada', 'Higganum CT', 'Frenchtown MT', 'McClane', 'Gville, Fl', 'Beijing', 'Spokane', 'NYC', 'Denver, CO', 'Bogotà', 'Sweden', 'Chapel Hill', 'Ga', 'Hays, Kansas USA', 'Manhattan Beach', 'Berkeley, CA', 'Leesburg', 'ny', 'Hoboken, NJ', 'Earth', 'Phoenix, AZ', '<br/>', 'Hoffman Estates, IL', 'CLT', 'Minnesota', 'Georgia', 'Northern California', 'Ny', 'Calgary, AB', 'UWS', 'Cambridge, MA', 'Southern California', 'Philly', 'Toronto, Canada', 'Bay Area', 'Citrus Heights', 'Washington', 'ky', 'Vancouver, Canada', 'Boca Raton, Florida', 'Philadelphia, PA', 'austin, tx', 'NJ', 'Mesa, AZ', 'Somewhere', 'US Refugee CANADA', 'Utah', 'Illimois', 'Bartlesville, OK', 'Washington, DC', 'Sydney Australia', 'Minneapolis', 'Colorado', 'Chapel Hill, NC', 'Napa, Ca', 'colombia', 'Toronto', 'urbana, il', 'Long Island N.Y.', 'Ontario', 'AZ', 'Fl', 'brooklyn', 'FL', 'Greenwich Village, NYC', 'earth', 'Amherst, MA', 'Tennessee', 'Brooklyn', 'Halfmoon, NY', 'Cormier', 'Davis, Ca', 'St. Louis Mo', 'Lafayette, CO', 'Evanston, IL', 'Huntington Beach, CA', 'San Diego', 'Beijing, China', 'Stockholm', 'Mexico City', 'Santa Fe NM', 'Upstate NY', 'Cleveland, OH', 'Puget Sound', 'PB San Diego', 'nyc', 'Ringoes, NJ', 'NY', 'Boston', 'IL', 'Des Moines', 'CT', 'San Jose', 'Bothell, WA', 'Eastern WA', 'nj', 'Hong Kong', 'Beyond the Beltway state of mind', 'Kingston, PA', 'Downtown Verona NJ', 'Bellingham, WA', 'not the USA', 'Albany', 'victoria, b.c., canada', 'Hartford', 'St Louis', 'Whereverthedoggoes,USA', 'Idaho', 'Etna California', 'Park City, Utah, from Boston', 'Brooklyn, NY', 'USA', 'Boston MA', 'Texas', 'White Plains, NY', 'Providence', 'Palo Alto, CA', 'London UK', 'Regba, Israel', 'Bellerose Terrace', 'Denmark', 'Bermuda', 'Wash DC', 'new york city', 'seattle', 'Hartland, WI', 'San diego', 'Marblemount, Washington', 'Akron, OH', 'Portland OR', 'Sonoma County', 'camarillo, ca', 'San Francisco, CA', 'Clawson, Mich', 'phoenix', 'West of the 100th Meridian', 'Rye', 'Michigan', 'charlottesville', 'Portland, OR', 'The internets', 'WestPark,  Quebec', 'Nyc', 'Australia', 'Tsk', 'Orlando, Florida', 'Tucson Arizona', 'US', 'Paris', 'Woodstock NY', 'Virginia', 'Tampa', 'usa', 'Phoenix', 'you never did. . .', 'Yakima, WA', 'Ambler PA', 'livingston nj', 'Durham, NC', 'Not in NY', 'Homestead Florida', 'British Columbia', 'Austin', 'Cleveland', 'Houston', 'Space', 'Singapore', 'Arlington, MA', 'Issaquah, WA', 'new jersey', 'thailand', 'New Mexico', 'Los Angeles', 'San Francsico,CA', 'Bakersfield, CA', 'Devereaux', 'Los Angeles CA', 'Baltimore', 'Ithaca', 'tacoma,wa', 'Atlanta', 'Northeast', 'Piscataway, NJ', 'In the Snow', 'Portland', 'New York', 'Montana', 'Dallas', 'Ohio', 'North Carolina', 'Evanston', 'Middlesex County, NJ', 'Vancouver', 'China', 'Jerusalem, Israel', 'Sacramento', 'St. Louis', 'chicago', 'NC', 'Washington DC Area', 'NYS', 'Lake Katrine, NY', 'TRUMBULL', 'New York, NY', 'California Central Coast', 'englewood, nj', 'Hanapepe, HI', 'Qc', 'Pasadena', 'Jersey City, NJ', 'Omaha, NE', 'Madison WI', 'San Francisco', 'Kingston, ON, Canada', 'california', 'Fukuoka,Japan', 'Potomac, MD', 'new zealand', 'Rowayton CT', 'Sioux Falls, SD', 'the new world', 'New Jersey', 'CA', 'undefined', 'Long Island, NY', 'LA', 'Rochester', 'Washington, D.C.', 'Oakland, CA', 'Vero Beach, Fla.', 'Honolulu', 'the emerald triangle', 'freed', 'Usa', 'Vancouver BC', 'Princeton,  NJ', 'New York City', 'Manhattan, NYC', 'The Village', 'Kansas City, MO', 'Austin, TX', 'Anywhere', 'upstateny', 'CO', 'PA', 'Seattle', 'Pasadena, Ca', 'Berkeley', 'Midland, MI', 'Portland,OR', 'New England', 'Palo Alto', 'Chicago', 'Wappingers Falls, NY', 'Connecticut', 'us', 'California', "I'm out in the woods. i akuhambi kahle emahlathini", 'Dallas, TX'}

# %%
#Thus we can find the list of locations of users using NYTimes.com

# %%
#Generating a csv to store the locations of users of NYTimes.com
import csv
with open("que[2]/ana_[2]/NYT_userLocations.csv","w",encoding='utf-8') as myfile3:
    writer_ne = csv.writer(myfile3,lineterminator='\n')
    writer_ne.writerow(["Location"])
    for i in range(0,len(set(places))):
        writer_ne.writerow([places[i]])

# %%
#Thus we can conclude that the number of users on NYTimes.com, not happy with the result of the presidential election are more.
#As we can see the number of negative comments is more than the number of positive comments.
#The output of the analysis and comments after sorting have been stored in the csv file.
